# %%
y_actual = [5, 1.5, 5, 6, 3]
y_pred = [4.5, 2.0, 6.0, 4.5, 2.9]

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2=r2_score(y_actual,y_pred)
mse=mean_squared_error(y_actual,y_pred)
rmse=pow(mse,(1/2))
mae=mean_absolute_error(y_actual,y_pred)

# %%
print(r2)
print(mse)
print(rmse)
print(mae)
# Out:
# 0.7151515151515151
# 0.752
# 0.867179335547152
# 0.72

# %%
import pandas as pd
df=pd.read_csv('Netflix Data new.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6403 entries, 0 to 6402
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   N_id             6403 non-null   int64
#  1   Title            6403 non-null   object
#  2   Main Genre       6403 non-null   object
#  3   Sub Genres       6403 non-null   object
#  4   Release Year     6402 non-null   float64
#  5   Maturity Rating  6403 non-null   object
#  6   Original Audio   3767 non-null   object
#  7   Recommendations  6392 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 400.3+ KB

# %%
df.isnull().sum()
# Out:
# N_id                  0
# Title                 0
# Main Genre            0
# Sub Genres            0
# Release Year          1
# Maturity Rating       0
# Original Audio     2636
# Recommendations      11
# dtype: int64

# %%
# Function + Missing qiymatlar
def tozala(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='object':
                df[col].fillna(df[col].mode()[0],inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)
    return df

# %%
tozala(df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9804\3535276904.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(),inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_9804\3535276904.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# N_id               0
# Title              0
# Main Genre         0
# Sub Genres         0
# Release Year       0
# Maturity Rating    0
# Original Audio     0
# Recommendations    0
# dtype: int64

# %% [markdown]
# # Funksiya +Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def encodla(df):
    encoder = LabelEncoder()

    for col in df.columns.to_list(): 
        if df[col].dtype == 'object':
            if df[col].nunique() <= 6:
                dummies = pd.get_dummies(df[col], prefix=col, dtype=int)
                df.drop(columns=[col], inplace=True)
                df[dummies.columns] = dummies
            else:
                df[col] = encoder.fit_transform(df[col].astype(str))
    
    return df

# %%
df = encodla(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6403 entries, 0 to 6402
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   N_id                     6403 non-null   int64
#  1   Title                    6403 non-null   int64
#  2   Main Genre               6403 non-null   int64
#  3   Sub Genres               6403 non-null   int64
#  4   Release Year             6403 non-null   float64
#  5   Original Audio           6403 non-null   int64
#  6   Recommendations          6403 non-null   int64
#  7   Maturity Rating_A        6403 non-null   int64
#  8   Maturity Rating_U        6403 non-null   int64
#  9   Maturity Rating_U/A 13+  6403 non-null   int64
#  10  Maturity Rating_U/A 16+  6403 non-null   int64
#  11  Maturity Rating_U/A 7+   6403 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 600.4 KB

# %% [markdown]
# # Funksiya+Scaling

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
num_col=df.select_dtypes(include=['int64','float64']).columns

# %%
num_col
# Out:
# Index(['N_id', 'Title', 'Main Genre', 'Sub Genres', 'Release Year',
#        'Original Audio', 'Recommendations', 'Maturity Rating_A',
#        'Maturity Rating_U', 'Maturity Rating_U/A 13+',
#        'Maturity Rating_U/A 16+', 'Maturity Rating_U/A 7+'],
#       dtype='object')

# %%
scaler=StandardScaler()

# %%
def taqriban(df):
    df[num_col]=scaler.fit_transform(df[num_col])
    return(df)

# %%
taqriban(df)
# Out:
#            N_id     Title  Main Genre  Sub Genres  Release Year  \
# 0    -11.104310 -1.603977   -0.718151   -1.366312     -4.115243
# 1    -11.104309 -1.603431   -0.718151   -1.384518     -3.951141
# 2    -11.104038  0.957073   -0.718151   -1.359887     -4.607550
# 3    -11.104031 -1.599065   -0.718151   -1.359887     -4.279345
# 4    -11.101486 -1.578869   -0.270539   -0.493506     -4.771652
# ...         ...       ...         ...         ...           ...
# 6398   0.317704 -0.144419    1.519911   -0.442101     -0.176791
# 6399   0.317704  1.564585   -0.718151   -0.502073     -0.176791
# 6400   0.318305  0.403052    0.624686   -0.144383      0.807823
# 6401   0.318505  0.289519   -0.270539   -0.437818     -0.012688
# 6402   0.318506 -0.031977    1.519911   -0.444243     -0.176791
#
#       Original Audio  Recommendations  Maturity Rating_A  Maturity Rating_U  \
# 0           0.789238        -1.569497           1.564026          -0.201150
# ...

# %%
x=df.drop('Recommendations',axis=1)

# %%
y=df['Recommendations']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([-0.10794628, -0.1575122 ,  0.27544786, ..., -0.04443548,
#         0.35920219, -0.16483418], shape=(1281,))

# %%
r2=r2_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=pow(mse,(1/2))
mae=mean_absolute_error(y_test,y_pred)

# %%
print(r2)
print(mse)
print(rmse)
print(mae)
# Out:
# 0.10501243296408935
# 0.8883669491164735
# 0.9425322005727303
# 0.7958719217136624

# %% [markdown]
# # HULOSa qilib aytganda r2 juda past model yaxshi ishlamayotganidan dalolat beradi input va outputlar orasidagi munosabat yaxshi organmangan
