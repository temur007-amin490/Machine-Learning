# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd   #   Kutubxona

# %%
# Avvalo install qilishimiz kerak 
# 1 pip install pandas

# %%
df=pd.read_csv('telefon turini aniqlash2.csv')

# %%
df=pd.read_csv('telefon turini aniqlash2.csv')   # datani vis codega o'rnatish

# %%
df.head()   # tepadan 5 ta qatorni ko'rish
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi      Rangi  Vazni  ...  \
# 0            1   0             7               0.6      Qizil    188  ...
# 1            0   1            53               0.7     Yashil    136  ...
# 2            2   1            41               0.9      Sariq    145  ...
# 3            0   0            10               0.8  Jigarrang    131  ...
# 4           13   1            44               0.6         Oq    141  ...
#
#    Qurilma ekran kengligi(pix)   ram  Qurilma xajmi(cm)  \
# 0                        756.0  2549                9.0
# ...

# %%
df.tail()    # Pastdan 5 ta qatorni ko'rish

# %%
df.head(10)
# Out:
#    battereya_hajmi  blutus  protsessor_tezligi  ikkita simkartalik  \
# 0              842       0                 2.2                   0
# 1             1021       1                 0.5                   1
# 2              563       1                 0.5                   1
# 3              615       1                 2.5                   0
# 4             1821       1                 1.2                   0
# 5             1859       0                 0.5                   1
# 6             1821       0                 1.7                   0
# 7             1954       0                 0.5                   1
# 8             1954       0                 0.5                   1
# 9             1445       1                 0.5                   0
#
#    Oldi_kamera  4G  Ichki_xotira  tel_ingichgaligi      Rangi  Vazni  ...  \
# 0            1   0             7               0.6      Qizil    188  ...
# 1            0   1            53               0.7     Yashil    136  ...
# ...

# %%
df.info()   # data xaqida umumiy malumot olish
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2001 non-null   int64
#  1   blutus                         2001 non-null   int64
#  2   protsessor_tezligi             2001 non-null   float64
#  3   ikkita simkartalik             2001 non-null   int64
#  4   Oldi_kamera                    2001 non-null   int64
#  5   4G                             2001 non-null   int64
#  6   Ichki_xotira                   2001 non-null   int64
#  7   tel_ingichgaligi               1998 non-null   float64
#  8   Rangi                          2001 non-null   object
#  9   Vazni                          2001 non-null   int64
#  10  Protsessor yadrolari soni      2000 non-null   float64
#  11  Asosiy kamera                  1999 non-null   float64
# ...

# %%
# Object= hello, -, 2023-20-09, 123/34, 123$34

# %%
df.isnull().sum()# tushub qolgan elementlarni ajratib yozish
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 3
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2001 non-null   int64
#  1   blutus                         2001 non-null   int64
#  2   protsessor_tezligi             2001 non-null   float64
#  3   ikkita simkartalik             2001 non-null   int64
#  4   Oldi_kamera                    2001 non-null   int64
#  5   4G                             2001 non-null   int64
#  6   Ichki_xotira                   2001 non-null   int64
#  7   tel_ingichgaligi               1998 non-null   float64
#  8   Rangi                          2001 non-null   object
#  9   Vazni                          2001 non-null   int64
#  10  Protsessor yadrolari soni      2000 non-null   float64
#  11  Asosiy kamera                  1999 non-null   float64
# ...

# %% [markdown]
# # Tushub qolgan elementlarni to'ldirish

# %%
# tushib qolgan elementlar bor ustunlarni tashlab  tashlab yuborish
df.dropna(axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2001 non-null   int64
#  1   blutus                         2001 non-null   int64
#  2   protsessor_tezligi             2001 non-null   float64
#  3   ikkita simkartalik             2001 non-null   int64
#  4   Oldi_kamera                    2001 non-null   int64
#  5   4G                             2001 non-null   int64
#  6   Ichki_xotira                   2001 non-null   int64
#  7   Rangi                          2001 non-null   object
#  8   Vazni                          2001 non-null   int64
#  9   ram                            2001 non-null   int64
#  10  Bir_quvvatlashdagi gaplashish  2001 non-null   int64
#  11  3g                             2001 non-null   int64
# ...

# %%
df.isnull().sum()# tushub qolgan elementlarni ajratib yozish
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# tel_ingichgaligi                 3
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
df.drop(columns=['tel_ingichgaligi'], axis=1, inplace=True)

# %%
df.isnull().sum()# tushub qolgan elementlarni ajratib yozish
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
df.drop(columns=['tel_ingichgaligi'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   battereya_hajmi                2001 non-null   int64
#  1   blutus                         2001 non-null   int64
#  2   protsessor_tezligi             2001 non-null   float64
#  3   ikkita simkartalik             2001 non-null   int64
#  4   Oldi_kamera                    2001 non-null   int64
#  5   4G                             2001 non-null   int64
#  6   Ichki_xotira                   2001 non-null   int64
#  7   Rangi                          2001 non-null   object
#  8   Vazni                          2001 non-null   int64
#  9   Protsessor yadrolari soni      2000 non-null   float64
#  10  Asosiy kamera                  1999 non-null   float64
#  11  Qurilma xajmi(pix)             1999 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        1
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
#Mean bn to'ldirish
df['Protsessor yadrolari soni'].fillna(df['Protsessor yadrolari soni'].mean(), inplace=True)
# Out:
# C:\Users\davro\AppData\Local\Temp\ipykernel_26520\372643331.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Protsessor yadrolari soni'].fillna(df['Protsessor yadrolari soni'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        0
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             2
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
#inplace=True   ortiqcha o'zgaruvchi qo'shishni oldini oladi

# %%
#Mean bn to'ldirish
df['Qurilma xajmi(pix).1'].fillna(df['Qurilma xajmi(pix).1'].mean(), inplace=True)
# Out:
# C:\Users\davro\AppData\Local\Temp\ipykernel_26520\2579508016.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Qurilma xajmi(pix).1'].fillna(df['Qurilma xajmi(pix).1'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        0
# Asosiy kamera                    2
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             0
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64

# %%
#Mean bn to'ldirish
df['Asosiy kamera'].fillna(df['Asosiy kamera'].mode()[0], inplace=True)
# Out:
# C:\Users\davro\AppData\Local\Temp\ipykernel_26520\1034873704.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Asosiy kamera'].fillna(df['Asosiy kamera'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# battereya_hajmi                  0
# blutus                           0
# protsessor_tezligi               0
# ikkita simkartalik               0
# Oldi_kamera                      0
# 4G                               0
# Ichki_xotira                     0
# Rangi                            0
# Vazni                            0
# Protsessor yadrolari soni        0
# Asosiy kamera                    0
# Qurilma xajmi(pix)               2
# Qurilma ekran kengligi(pix)      3
# ram                              0
# Qurilma xajmi(cm)                1
# Qurilma ekran kengligi(cm)       1
# Bir_quvvatlashdagi gaplashish    0
# 3g                               0
# Qurilma xajmi(pix).1             0
# sensorli                         0
# wifi                             0
# telefon_turi                     0
# dtype: int64
